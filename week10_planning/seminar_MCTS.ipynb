# %% [markdown]
# ## Seminar: Monte-carlo tree search (5 pts)
#
# Monte Carlo tree search (MCTS) is a heuristic search algorithm, which shows cool results in challenging domains such as Go and chess. The algorithm builds a search tree, iteratively traverses it, and evaluates its nodes using a Monte-Carlo simulation.
#
# In this seminar, we'll implement a MCTS([[1]](#1), [[2]](#2)) planning and use it to solve some Gym envs.
#
# ![image.png](https://i.postimg.cc/6QmwnjPS/image.png)

# %% [markdown]
# __How it works?__
# We just start with an empty tree and expand it. There are several common procedures.
#
# __1) Selection__
# Starting from the root, recursively select the node that corresponds to the tree policy.
#
# There are several options for tree policies, which we saw earlier as exploration strategies: epsilon-greedy, Thomson sampling, UCB-1. It was shown that in MCTS, UCB-1 achieves a good result. Further, we will consider the one, but you can try to use others.
#
# Following the UCB-1 tree policy, we will choose an action that, on one hand, we expect to have the highest return, and on the other hand, we haven't explored much.
#
#
# $$
# \dot{a} = argmax_{a} \dot{Q}(s, a)
# $$
#
# $$
# \dot{Q}(s, a) = Q(s, a) + C_p \sqrt{\frac{2 \log {N}}{n_a}}
# $$
#
# where:
# - $N$ - number of times we have visited state $s$,
# - $n_a$ - number of times we have taken action $a$,
# - $C_p$ - exploration balance parameter, which is performed between exploration and exploitation.
#
# Using Hoeffding inequality for rewards $R \in [0,1]$ it can be shown [[3]](#3) that optimal $C_p = 1/\sqrt{2}$. For rewards outside this range, the parameter should be tuned. We'll be using 10, but you can experiment with other values.
#
# __2) Expansion__
# After the selection procedure, we can achieve a leaf node or node in which we don't complete actions. In this case, we expand the tree by feasible actions and get new state nodes.
#
# __3) Simulation__
# How we can estimate node Q-values? The idea is to estimate action values for a given _rollout policy_ by averaging the return of many simulated trajectories from the current node. Simply, we can play with random or some special policy or use some model that can estimate it.
#
# __4) Backpropagation__
# The reward of the last simulation is backed up through the traversed nodes and propagates Q-value estimations, upwards to the root.
#
# $$
# Q({\text{parent}}, a) = r + \gamma \cdot Q({\text{child}}, a)
# $$
#
# There are a lot modifications of MCTS, more details about it you can find in this paper [[4]](#4)

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !pip install -q gymnasium

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ---
#
# But before we do that, we first need to make a wrapper for Gymnasium environments to allow saving and loading game states to facilitate backtracking.

# %%
import gymnasium as gym
from pickle import dumps, loads
from collections import namedtuple

# a container for get_result function below. Works just like tuple, but prettier
ActionResult = namedtuple(
    "action_result", ("snapshot", "observation", "reward", "is_done", "info"))


class WithSnapshots(gym.Wrapper):
    """
    Creates a wrapper that supports saving and loading environemnt states.
    Required for planning algorithms.

    This class will have access to the core environment as self.env, e.g.:
    - self.env.reset()           #reset original env
    - self.env.ale.cloneState()  #make snapshot for atari. load with .restoreState()
    - ...

    You can also use reset() and step() directly for convenience.
    - s, _ = self.reset()                   # same as self.env.reset()
    - s, r, terminated, truncated, _ = self.step(action)  # same as self.env.step(action)
    
    Note that while you may use self.render(), it will spawn a window that cannot be pickled.
    Thus, you will need to call self.close() before pickling will work again.
    """

    def get_snapshot(self, render=False):
        """
        :returns: environment state that can be loaded with load_snapshot 
        Snapshots guarantee same env behaviour each time they are loaded.

        Warning! Snapshots can be arbitrary things (strings, integers, json, tuples)
        Don't count on them being pickle strings when implementing MCTS.

        Developer Note: Make sure the object you return will not be affected by 
        anything that happens to the environment after it's saved.
        You shouldn't, for example, return self.env. 
        In case of doubt, use pickle.dumps or deepcopy.

        """
        if render:
            self.render()  # close popup windows since we can't pickle them
            self.close()
            
        self.unwrapped.screen = None
        self.unwrapped.clock = None
        self.unwrapped.surf = None

        return dumps(self.env)

    def load_snapshot(self, snapshot, render=False):
        """
        Loads snapshot as current env state.
        Should not change snapshot inplace (in case of doubt, deepcopy).
        """

        assert not hasattr(self, "_monitor") or hasattr(
            self.env, "_monitor"), "can't backtrack while recording"

        if render:
            self.render()  # close popup windows since we can't load into them
            self.close()
        self.env = loads(snapshot)

    def get_result(self, snapshot, action):
        """
        A convenience function that 
        - loads snapshot, 
        - commits action via self.step,
        - and takes snapshot again :)

        :returns: next snapshot, next_observation, reward, is_done, info

        Basically it returns next snapshot and almost everything that env.step would have returned.
        Note that is_done = terminated or truncated
        """
        self.load_snapshot(snapshot)
        s, _ = self.reset()                   # same as self.env.reset()
        s, r, terminated, truncated, info = self.step(action)  # same as self.env.step(action)
        is_done = terminated or truncated
        snapshot = self.get_snapshot()
        
        return ActionResult(
            snapshot,  # fill in the variables
            s,
            r,
            is_done,
            info,
        )

# %% [markdown]
# ### Try out snapshots:
# Let`s check our wrapper. At first, reset environment and save it, further randomly play some actions and restore our environment from the snapshot. It should be the same as our previous initial state.

# %%
# make env
env = WithSnapshots(gym.make("CartPole-v1",
                             render_mode="rgb_array",
                             max_episode_steps=200))
env.reset()

n_actions = env.action_space.n

# %%
print("initial_state:")
plt.imshow(env.render())
env.close()

# create first snapshot
snap0 = env.get_snapshot()
# Out:
# initial_state:

# %%
# play without making snapshots (faster)
while True:
    _, _, terminated, truncated, _ = env.step(env.action_space.sample())
    if terminated:
        print("Whoops! We died!")
        break
    if truncated:
        print("Time is over!")
        break

print("final state:")
plt.imshow(env.render())
env.close()
# Out:
# Whoops! We died!
# final state:

# %%
# reload initial state
env.load_snapshot(snap0)

print("\n\nAfter loading snapshot")
plt.imshow(env.render())
env.close()
# Out:
# After loading snapshot

# %%
# get outcome (snapshot, observation, reward, is_done, info)
res = env.get_result(snap0, env.action_space.sample())

snap1, observation, reward = res[:3]

# second step
res2 = env.get_result(snap1, env.action_space.sample())

# %% [markdown]
# # MCTS: Monte-Carlo tree search
#
#
# We will start by implementing the `Node` class - a simple class that acts like MCTS node and supports some of the MCTS algorithm steps.
#
# This MCTS implementation makes some assumptions about the environment, you can find those _in the notes section at the end of the notebook_.

# %%
assert isinstance(env, WithSnapshots)

# %%
class Node:
    """A tree node for MCTS.
    
    Each Node corresponds to the result of performing a particular action (self.action)
    in a particular state (self.parent), and is essentially one arm in the multi-armed bandit that
    we model in that state."""

    # metadata:
    parent = None  # parent Node
    qvalue_sum = 0.  # sum of Q-values from all visits (numerator)
    times_visited = 0  # counter of visits (denominator)

    def __init__(self, parent, action):
        """
        Creates and empty node with no children.
        Does so by commiting an action and recording outcome.

        :param parent: parent Node
        :param action: action to commit from parent Node
        """

        self.parent = parent
        self.action = action
        self.children = set()  # set of child nodes

        # get action outcome and save it
        res = env.get_result(parent.snapshot, action)
        self.snapshot, self.observation, self.immediate_reward, self.is_done, _ = res

    def is_leaf(self):
        return len(self.children) == 0

    def is_root(self):
        return self.parent is None

    def get_qvalue_estimate(self):
        return self.qvalue_sum / self.times_visited if self.times_visited != 0 else 0

    def ucb_score(self, scale=10, max_value=1e100):
        """
        Computes ucb1 upper bound using current value and visit counts for node and it's parent.

        :param scale: Multiplies upper bound by that. From Hoeffding inequality,
                      assumes reward range to be [0, scale].
        :param max_value: a value that represents infinity (for unvisited nodes).

        """

        if self.times_visited == 0:
            return max_value

        # compute ucb-1 additive component (to be added to mean value)
        # hint: you can use self.parent.times_visited for N times node was considered,
        # and self.times_visited for n times it was visited

        U = np.sqrt(2 * np.log(self.parent.times_visited)) / self.times_visited

        return self.get_qvalue_estimate() + scale * U

    # MCTS steps
    def select_bestq_leaf(self):
        """
        Picks the leaf with the highest priority to expand.
        Does so by recursively picking nodes with the best UCB-1 score until it reaches a leaf.
        """
        if self.is_leaf():
            return self

        children = self.children

        # Select the child node with the highest UCB score. You might want to implement some heuristics
        # to break ties in a smart way, although CartPole should work just fine without them.
        best_score = -1e+12
        best_child = None
        for child in children:
            child_score = child.get_qvalue_estimate()
            if best_score < child_score:
                best_child = child
                best_score = child_score
        return best_child.select_bestq_leaf()
    

    def select_best_leaf(self):
        """
        Picks the leaf with the highest priority to expand.
        Does so by recursively picking nodes with the best UCB-1 score until it reaches a leaf.
        """
        if self.is_leaf():
            return self

        children = self.children

        # Select the child node with the highest UCB score. You might want to implement some heuristics
        # to break ties in a smart way, although CartPole should work just fine without them.
        best_score = -1e+12
        best_child = None
        for child in children:
            child_score = child.ucb_score()
            if best_score < child_score:
                best_child = child
                best_score = child_score
        return best_child.select_best_leaf()

    def expand(self):
        """
        Expands the current node by creating all possible child nodes.
        Then returns one of those children.
        """

        assert not self.is_done, "can't expand from terminal state"

        for action in range(n_actions):
            self.children.add(Node(self, action))

        # If you have implemented any heuristics in select_best_leaf(), they will be used here.
        # Otherwise, this is equivalent to picking some undefined newly created child node.
        return self.select_best_leaf()

    def rollout(self, t_max=10**4):
        """
        Play the game from this state to the end (done) or for t_max steps.

        On each step, pick action at random (hint: env.action_space.sample()).

        Compute sum of rewards from the current state until the end of the episode.
        Note 1: use env.action_space.sample() for picking a random action.
        Note 2: if the node is terminal (self.is_done is True), just return self.immediate_reward.

        """

        # set env into the appropriate state
        env.load_snapshot(self.snapshot)
        obs = self.observation
        is_done = self.is_done

        if is_done:
            return self.immediate_reward
        
        rollout_reward = 0
        for t in range(t_max):
            obs, r, terminated, truncated, _ = env.step(env.action_space.sample())
            rollout_reward += r
            if terminated or truncated:
                return rollout_reward


        return rollout_reward

    def propagate(self, child_qvalue):
        """
        Uses child Q-value (sum of rewards) to update parents recursively.
        """
        # compute node Q-value
        my_qvalue = self.immediate_reward + child_qvalue

        # update qvalue_sum and times_visited
        self.qvalue_sum += my_qvalue
        self.times_visited += 1

        # propagate upwards
        if not self.is_root():
            self.parent.propagate(my_qvalue)

    def safe_delete(self):
        """safe delete to prevent memory leak in some python versions"""
        del self.parent
        for child in self.children:
            child.safe_delete()
            del child

# %%
class Root(Node):
    def __init__(self, snapshot, observation):
        """
        creates special node that acts like tree root
        :snapshot: snapshot (from env.get_snapshot) to start planning from
        :observation: last environment observation
        """

        self.parent = self.action = None
        self.children = set()  # set of child nodes

        # root: load snapshot and observation
        self.snapshot = snapshot
        self.observation = observation
        self.immediate_reward = 0
        self.is_done = False

    @staticmethod
    def from_node(node):
        """initializes node as root"""
        root = Root(node.snapshot, node.observation)
        # copy data
        copied_fields = ["qvalue_sum", "times_visited", "children", "is_done"]
        for field in copied_fields:
            setattr(root, field, getattr(node, field))
        return root

# %% [markdown]
# ## Main MCTS loop
#
# With all we implemented, MCTS boils down to a trivial piece of code.

# %%
def plan_mcts(root, n_iters=10):
    """
    builds tree with monte-carlo tree search for n_iters iterations
    :param root: tree node to plan from
    :param n_iters: how many select-expand-simulate-propagete loops to make
    """
    for _ in range(n_iters):
        node = root.select_best_leaf()
        
        if node.is_done:
            # All rollouts from a terminal node are empty, and thus have 0 reward.
            node.propagate(0)
        else:
            # Expand the best leaf. Perform a rollout from it. Propagate the results upwards.
            # Note that here you have some leeway in choosing where to propagate from.
            # Any reasonable choice should work.
            new_node = node.expand()
            print(new_node)
            new_node.propagate(new_node.rollout())

# %% [markdown]
# ## Plan and execute
#
# Let's use our MCTS implementation to find the optimal policy.

# %%
env = WithSnapshots(gym.make("CartPole-v1", render_mode="rgb_array", max_episode_steps=200))
root_observation, _ = env.reset()
root_snapshot = env.get_snapshot()
root = Root(root_snapshot, root_observation)

# %%
# plan from root:
plan_mcts(root, n_iters=1000)
# Out:
# <__main__.Node object at 0x000001D368232210>
# <__main__.Node object at 0x000001D367F04690>
# <__main__.Node object at 0x000001D36CECB490>
# <__main__.Node object at 0x000001D36CEBBAC0>
# <__main__.Node object at 0x000001D3686FBC50>
# <__main__.Node object at 0x000001D3623CE030>
# <__main__.Node object at 0x000001D36AD712B0>
# <__main__.Node object at 0x000001D36846B790>
# <__main__.Node object at 0x000001D36CE8B290>
# <__main__.Node object at 0x000001D3684ED5A0>
# <__main__.Node object at 0x000001D367F2D090>
# <__main__.Node object at 0x000001D3712C6030>
# <__main__.Node object at 0x000001D3712C7930>
# <__main__.Node object at 0x000001D3712C4E10>
# <__main__.Node object at 0x000001D367EC84B0>
# <__main__.Node object at 0x000001D367ECA030>
# <__main__.Node object at 0x000001D367ECA530>
# <__main__.Node object at 0x000001D367ECACB0>
# <__main__.Node object at 0x000001D367EC8C30>
# <__main__.Node object at 0x000001D367ECB430>
# <__main__.Node object at 0x000001D367EC8AF0>
# <__main__.Node object at 0x000001D367EC9B30>
# <__main__.Node object at 0x000001D367EC9D10>
# <__main__.Node object at 0x000001D367ECB110>
# <__main__.Node object at 0x000001D367ECAD50>
# <__main__.Node object at 0x000001D367ECB2F0>
# <__main__.Node object at 0x000001D367ECB390>
# <__main__.Node object at 0x000001D367ECAA30>
# <__main__.Node object at 0x000001D367EC8F50>
# <__main__.Node object at 0x000001D367ECA490>
# <__main__.Node object at 0x000001D367ECA2B0>
# <__main__.Node object at 0x000001D367EC9810>
# <__main__.Node object at 0x000001D367ECA350>
# <__main__.Node object at 0x000001D367ECBE30>
# <__main__.Node object at 0x000001D367EC9130>
# <__main__.Node object at 0x000001D367EC8190>
# <__main__.Node object at 0x000001D367ECA710>
# <__main__.Node object at 0x000001D367EC8910>
# <__main__.Node object at 0x000001D367EC8410>
# <__main__.Node object at 0x000001D367ECBD90>
# <__main__.Node object at 0x000001D367EC9630>
# <__main__.Node object at 0x000001D367ECB9D0>
# <__main__.Node object at 0x000001D367ECBBB0>
# <__main__.Node object at 0x000001D367EC8690>
# <__main__.Node object at 0x000001D367ECB890>
# <__main__.Node object at 0x000001D367EC8E10>
# <__main__.Node object at 0x000001D367EC9590>
# <__main__.Node object at 0x000001D367EC8CD0>
# <__main__.Node object at 0x000001D3685062B0>
# <__main__.Node object at 0x000001D368504B90>
# <__main__.Node object at 0x000001D368506A30>
# <__main__.Node object at 0x000001D368505E50>
# <__main__.Node object at 0x000001D368506C10>
# <__main__.Node object at 0x000001D3685074D0>
# <__main__.Node object at 0x000001D368506F30>
# <__main__.Node object at 0x000001D368506CB0>
# <__main__.Node object at 0x000001D368506530>
# <__main__.Node object at 0x000001D368504910>
# <__main__.Node object at 0x000001D368504CD0>
# <__main__.Node object at 0x000001D3685053B0>
# <__main__.Node object at 0x000001D368506990>
# <__main__.Node object at 0x000001D3685042D0>
# <__main__.Node object at 0x000001D368504E10>
# <__main__.Node object at 0x000001D368505DB0>
# <__main__.Node object at 0x000001D368504A50>
# <__main__.Node object at 0x000001D368506350>
# <__main__.Node object at 0x000001D368505090>
# <__main__.Node object at 0x000001D368506490>
# <__main__.Node object at 0x000001D368507250>
# <__main__.Node object at 0x000001D368504410>
# <__main__.Node object at 0x000001D368505A90>
# <__main__.Node object at 0x000001D368505630>
# <__main__.Node object at 0x000001D368507610>
# <__main__.Node object at 0x000001D368504230>
# <__main__.Node object at 0x000001D368505BD0>
# <__main__.Node object at 0x000001D368505310>
# <__main__.Node object at 0x000001D368504F50>
# <__main__.Node object at 0x000001D368504EB0>
# <__main__.Node object at 0x000001D3685063F0>
# <__main__.Node object at 0x000001D368506210>
# <__main__.Node object at 0x000001D368505450>
# <__main__.Node object at 0x000001D3685056D0>
# <__main__.Node object at 0x000001D3685071B0>
# <__main__.Node object at 0x000001D3685067B0>
# <__main__.Node object at 0x000001D368507890>
# <__main__.Node object at 0x000001D368505590>
# <__main__.Node object at 0x000001D368505D10>
# <__main__.Node object at 0x000001D368507390>
# <__main__.Node object at 0x000001D3685049B0>
# <__main__.Node object at 0x000001D368462990>
# <__main__.Node object at 0x000001D367DB9F90>
# <__main__.Node object at 0x000001D367DBA490>
# <__main__.Node object at 0x000001D367DB9130>
# <__main__.Node object at 0x000001D367E99310>
# <__main__.Node object at 0x000001D3682E60D0>
# <__main__.Node object at 0x000001D3682E6490>
# <__main__.Node object at 0x000001D368AC84B0>
# <__main__.Node object at 0x000001D368AC8190>
# <__main__.Node object at 0x000001D368AC9310>
# <__main__.Node object at 0x000001D368AC8050>
# <__main__.Node object at 0x000001D368AC8E10>
# <__main__.Node object at 0x000001D368AC8690>
# <__main__.Node object at 0x000001D368AC8C30>
# <__main__.Node object at 0x000001D368ACB6B0>
# <__main__.Node object at 0x000001D368ACAFD0>
# <__main__.Node object at 0x000001D368AC8F50>
# <__main__.Node object at 0x000001D368ACB430>
# <__main__.Node object at 0x000001D368AC93B0>
# <__main__.Node object at 0x000001D368AC8550>
# <__main__.Node object at 0x000001D368ACA490>
# <__main__.Node object at 0x000001D368ACA030>
# <__main__.Node object at 0x000001D368ACBD90>
# <__main__.Node object at 0x000001D368AC8410>
# <__main__.Node object at 0x000001D368AC9A90>
# <__main__.Node object at 0x000001D368AC8910>
# <__main__.Node object at 0x000001D368AC9090>
# <__main__.Node object at 0x000001D368AC8230>
# <__main__.Node object at 0x000001D368AC8730>
# <__main__.Node object at 0x000001D368AC9590>
# <__main__.Node object at 0x000001D368AC9810>
# <__main__.Node object at 0x000001D368AC80F0>
# <__main__.Node object at 0x000001D368ACBB10>
# <__main__.Node object at 0x000001D368AC82D0>
# <__main__.Node object at 0x000001D368ACA0D0>
# <__main__.Node object at 0x000001D368AC89B0>
# <__main__.Node object at 0x000001D368AC9D10>
# <__main__.Node object at 0x000001D368ACBC50>
# <__main__.Node object at 0x000001D368ACAA30>
# <__main__.Node object at 0x000001D368ACA5D0>
# <__main__.Node object at 0x000001D368ACB1B0>
# <__main__.Node object at 0x000001D368ACB110>
# <__main__.Node object at 0x000001D368ACB610>
# <__main__.Node object at 0x000001D368ACA2B0>
# <__main__.Node object at 0x000001D368ACA990>
# <__main__.Node object at 0x000001D368ACAE90>
# <__main__.Node object at 0x000001D368AC9C70>
# <__main__.Node object at 0x000001D368ACAF30>
# <__main__.Node object at 0x000001D368ACB890>
# <__main__.Node object at 0x000001D368AC8A50>
# <__main__.Node object at 0x000001D368AC9DB0>
# <__main__.Node object at 0x000001D368ACB390>
# <__main__.Node object at 0x000001D368AC9950>
# <__main__.Node object at 0x000001D368ACBBB0>
# <__main__.Node object at 0x000001D368AC8D70>
# <__main__.Node object at 0x000001D368ACA7B0>
# <__main__.Node object at 0x000001D368ACA710>
# <__main__.Node object at 0x000001D368AD9770>
# <__main__.Node object at 0x000001D368AD89B0>
# <__main__.Node object at 0x000001D368AD8C30>
# <__main__.Node object at 0x000001D368AD8230>
# <__main__.Node object at 0x000001D368AD8B90>
# <__main__.Node object at 0x000001D368AD8190>
# <__main__.Node object at 0x000001D368AD96D0>
# <__main__.Node object at 0x000001D368AD8410>
# <__main__.Node object at 0x000001D368AD99F0>
# <__main__.Node object at 0x000001D368AD98B0>
# <__main__.Node object at 0x000001D368AD9810>
# <__main__.Node object at 0x000001D368AD9A90>
# <__main__.Node object at 0x000001D368AD9D10>
# <__main__.Node object at 0x000001D368AD9630>
# <__main__.Node object at 0x000001D368AD8F50>
# <__main__.Node object at 0x000001D368AD8E10>
# <__main__.Node object at 0x000001D368AD9590>
# <__main__.Node object at 0x000001D368AD9090>
# <__main__.Node object at 0x000001D368AD9130>
# <__main__.Node object at 0x000001D368AD9450>
# <__main__.Node object at 0x000001D368AD82D0>
# <__main__.Node object at 0x000001D368AD93B0>
# <__main__.Node object at 0x000001D368AD9310>
# <__main__.Node object at 0x000001D3682D4CD0>
# <__main__.Node object at 0x000001D3682D63F0>
# <__main__.Node object at 0x000001D3682D4C30>
# <__main__.Node object at 0x000001D3682D5D10>
# <__main__.Node object at 0x000001D3682D7930>
# <__main__.Node object at 0x000001D3682D6210>
# <__main__.Node object at 0x000001D3682D7D90>
# <__main__.Node object at 0x000001D3682D4050>
# <__main__.Node object at 0x000001D3682D4870>
# <__main__.Node object at 0x000001D3682D6E90>
# <__main__.Node object at 0x000001D3682D42D0>
# <__main__.Node object at 0x000001D3682D4190>
# <__main__.Node object at 0x000001D3682D7E30>
# <__main__.Node object at 0x000001D3682D7B10>
# <__main__.Node object at 0x000001D3682D6490>
# <__main__.Node object at 0x000001D3682D6D50>
# <__main__.Node object at 0x000001D3682D74D0>
# <__main__.Node object at 0x000001D3682D4EB0>
# <__main__.Node object at 0x000001D3682D6A30>
# <__main__.Node object at 0x000001D3682D5F90>
# <__main__.Node object at 0x000001D3682D5A90>
# <__main__.Node object at 0x000001D3682D4F50>
# <__main__.Node object at 0x000001D3682D6990>
# <__main__.Node object at 0x000001D3682D5130>
# <__main__.Node object at 0x000001D3682D4E10>
# <__main__.Node object at 0x000001D3682D6710>
# <__main__.Node object at 0x000001D3682D5590>
# <__main__.Node object at 0x000001D3682D7890>
# <__main__.Node object at 0x000001D3682D7430>
# <__main__.Node object at 0x000001D3682D7ED0>
# <__main__.Node object at 0x000001D3682D58B0>
# <__main__.Node object at 0x000001D3682D7250>
# <__main__.Node object at 0x000001D3682D6C10>
# <__main__.Node object at 0x000001D3682D77F0>
# <__main__.Node object at 0x000001D3682D76B0>
# <__main__.Node object at 0x000001D3682D5EF0>
# <__main__.Node object at 0x000001D3682D53B0>
# <__main__.Node object at 0x000001D3682D4910>
# <__main__.Node object at 0x000001D3682D56D0>
# <__main__.Node object at 0x000001D3682D5810>
# <__main__.Node object at 0x000001D3682D4690>
# <__main__.Node object at 0x000001D3682D71B0>
# <__main__.Node object at 0x000001D3682D7110>
# <__main__.Node object at 0x000001D3682D60D0>
# <__main__.Node object at 0x000001D3682D5310>
# <__main__.Node object at 0x000001D3682D4B90>
# <__main__.Node object at 0x000001D3682D7610>
# <__main__.Node object at 0x000001D3682D49B0>
# <__main__.Node object at 0x000001D3682D6CB0>
# <__main__.Node object at 0x000001D3682D6FD0>
# <__main__.Node object at 0x000001D3682D4410>
# <__main__.Node object at 0x000001D3682D4730>
# <__main__.Node object at 0x000001D3682BC2D0>
# <__main__.Node object at 0x000001D3682BC410>
# <__main__.Node object at 0x000001D3682BC4B0>
# <__main__.Node object at 0x000001D3682BC690>
# <__main__.Node object at 0x000001D3682BC730>
# <__main__.Node object at 0x000001D3682BC910>
# <__main__.Node object at 0x000001D3682BC9B0>
# <__main__.Node object at 0x000001D3682BCB90>
# <__main__.Node object at 0x000001D3682BCC30>
# <__main__.Node object at 0x000001D3682BCE10>
# <__main__.Node object at 0x000001D3682BCEB0>
# <__main__.Node object at 0x000001D3682BD090>
# <__main__.Node object at 0x000001D3682BD130>
# <__main__.Node object at 0x000001D3682BD310>
# <__main__.Node object at 0x000001D3682BD3B0>
# <__main__.Node object at 0x000001D3682BD590>
# <__main__.Node object at 0x000001D3682BD630>
# <__main__.Node object at 0x000001D3682BD810>
# <__main__.Node object at 0x000001D3682BD8B0>
# <__main__.Node object at 0x000001D3682BDA90>
# <__main__.Node object at 0x000001D3682BDB30>
# <__main__.Node object at 0x000001D3682BDD10>
# <__main__.Node object at 0x000001D3682BDDB0>
# <__main__.Node object at 0x000001D3682BDF90>
# <__main__.Node object at 0x000001D3682BE030>
# <__main__.Node object at 0x000001D3682BE210>
# <__main__.Node object at 0x000001D3682BE2B0>
# <__main__.Node object at 0x000001D3682BE490>
# <__main__.Node object at 0x000001D3682BE530>
# <__main__.Node object at 0x000001D3682BE710>
# <__main__.Node object at 0x000001D3682BE7B0>
# <__main__.Node object at 0x000001D3682BE990>
# <__main__.Node object at 0x000001D3682BEA30>
# <__main__.Node object at 0x000001D3682BEC10>
# <__main__.Node object at 0x000001D3682BECB0>
# <__main__.Node object at 0x000001D3682BEE90>
# <__main__.Node object at 0x000001D3682BEF30>
# <__main__.Node object at 0x000001D3682BF110>
# <__main__.Node object at 0x000001D3682BF1B0>
# <__main__.Node object at 0x000001D3682BF390>
# <__main__.Node object at 0x000001D3682BF430>
# <__main__.Node object at 0x000001D3682BF610>
# <__main__.Node object at 0x000001D3682BF6B0>
# <__main__.Node object at 0x000001D3682BF890>
# <__main__.Node object at 0x000001D3682BF930>
# <__main__.Node object at 0x000001D3682BFB10>
# <__main__.Node object at 0x000001D3682BFBB0>
# <__main__.Node object at 0x000001D3682BFD90>
# <__main__.Node object at 0x000001D3682BFE30>
# <__main__.Node object at 0x000001D3682BC190>
# <__main__.Node object at 0x000001D3682BC230>
# <__main__.Node object at 0x000001D3682542D0>
# <__main__.Node object at 0x000001D368254410>
# <__main__.Node object at 0x000001D3682544B0>
# <__main__.Node object at 0x000001D368254690>
# <__main__.Node object at 0x000001D368254730>
# <__main__.Node object at 0x000001D368254910>
# <__main__.Node object at 0x000001D3682549B0>
# <__main__.Node object at 0x000001D368254B90>
# <__main__.Node object at 0x000001D368254C30>
# <__main__.Node object at 0x000001D368254E10>
# <__main__.Node object at 0x000001D368254EB0>
# <__main__.Node object at 0x000001D368255090>
# <__main__.Node object at 0x000001D368255130>
# <__main__.Node object at 0x000001D368255310>
# <__main__.Node object at 0x000001D3682553B0>
# <__main__.Node object at 0x000001D368255590>
# <__main__.Node object at 0x000001D368255630>
# <__main__.Node object at 0x000001D368255810>
# <__main__.Node object at 0x000001D3682558B0>
# <__main__.Node object at 0x000001D368255A90>
# <__main__.Node object at 0x000001D368255B30>
# <__main__.Node object at 0x000001D368255D10>
# <__main__.Node object at 0x000001D368255DB0>
# <__main__.Node object at 0x000001D368255F90>
# <__main__.Node object at 0x000001D368256030>
# <__main__.Node object at 0x000001D368256210>
# <__main__.Node object at 0x000001D3682562B0>
# <__main__.Node object at 0x000001D368256490>
# <__main__.Node object at 0x000001D368256530>
# <__main__.Node object at 0x000001D368256710>
# <__main__.Node object at 0x000001D3682567B0>
# <__main__.Node object at 0x000001D368256990>
# <__main__.Node object at 0x000001D368256A30>
# <__main__.Node object at 0x000001D368256C10>
# <__main__.Node object at 0x000001D368256CB0>
# <__main__.Node object at 0x000001D368256E90>
# <__main__.Node object at 0x000001D368256F30>
# <__main__.Node object at 0x000001D368257110>
# <__main__.Node object at 0x000001D3682571B0>
# <__main__.Node object at 0x000001D368257390>
# <__main__.Node object at 0x000001D368257430>
# <__main__.Node object at 0x000001D368257610>
# <__main__.Node object at 0x000001D3682576B0>
# <__main__.Node object at 0x000001D368257890>
# <__main__.Node object at 0x000001D368257930>
# <__main__.Node object at 0x000001D368257B10>
# <__main__.Node object at 0x000001D368257BB0>
# <__main__.Node object at 0x000001D368257D90>
# <__main__.Node object at 0x000001D368257E30>
# <__main__.Node object at 0x000001D368254190>
# <__main__.Node object at 0x000001D368254230>
# <__main__.Node object at 0x000001D370F002D0>
# <__main__.Node object at 0x000001D370F00410>
# <__main__.Node object at 0x000001D370F004B0>
# <__main__.Node object at 0x000001D370F00690>
# <__main__.Node object at 0x000001D370F00730>
# <__main__.Node object at 0x000001D370F00910>
# <__main__.Node object at 0x000001D370F009B0>
# <__main__.Node object at 0x000001D370F00B90>
# <__main__.Node object at 0x000001D370F00C30>
# <__main__.Node object at 0x000001D370F00E10>
# <__main__.Node object at 0x000001D370F00EB0>
# <__main__.Node object at 0x000001D370F01090>
# <__main__.Node object at 0x000001D370F01130>
# <__main__.Node object at 0x000001D370F01310>
# <__main__.Node object at 0x000001D370F013B0>
# <__main__.Node object at 0x000001D370F01590>
# <__main__.Node object at 0x000001D370F01630>
# <__main__.Node object at 0x000001D370F01810>
# <__main__.Node object at 0x000001D370F018B0>
# <__main__.Node object at 0x000001D370F01A90>
# <__main__.Node object at 0x000001D370F01B30>
# <__main__.Node object at 0x000001D370F01D10>
# <__main__.Node object at 0x000001D370F01DB0>
# <__main__.Node object at 0x000001D370F01F90>
# <__main__.Node object at 0x000001D370F02030>
# <__main__.Node object at 0x000001D370F02210>
# <__main__.Node object at 0x000001D370F022B0>
# <__main__.Node object at 0x000001D370F02490>
# <__main__.Node object at 0x000001D370F02530>
# <__main__.Node object at 0x000001D370F02710>
# <__main__.Node object at 0x000001D370F027B0>
# <__main__.Node object at 0x000001D370F02990>
# <__main__.Node object at 0x000001D370F02A30>
# <__main__.Node object at 0x000001D370F02C10>
# <__main__.Node object at 0x000001D370F02CB0>
# <__main__.Node object at 0x000001D370F02E90>
# <__main__.Node object at 0x000001D370F02F30>
# <__main__.Node object at 0x000001D370F03110>
# <__main__.Node object at 0x000001D370F031B0>
# <__main__.Node object at 0x000001D370F03390>
# <__main__.Node object at 0x000001D370F03430>
# <__main__.Node object at 0x000001D370F03610>
# <__main__.Node object at 0x000001D370F036B0>
# <__main__.Node object at 0x000001D370F03890>
# <__main__.Node object at 0x000001D370F03930>
# <__main__.Node object at 0x000001D370F03B10>
# <__main__.Node object at 0x000001D370F03BB0>
# <__main__.Node object at 0x000001D370F03D90>
# <__main__.Node object at 0x000001D370F03E30>
# <__main__.Node object at 0x000001D370F00190>
# <__main__.Node object at 0x000001D370F00230>
# <__main__.Node object at 0x000001D370F0C2D0>
# <__main__.Node object at 0x000001D370F0C410>
# <__main__.Node object at 0x000001D370F0C4B0>
# <__main__.Node object at 0x000001D370F0C690>
# <__main__.Node object at 0x000001D370F0C730>
# <__main__.Node object at 0x000001D370F0C910>
# <__main__.Node object at 0x000001D370F0C9B0>
# <__main__.Node object at 0x000001D370F0CB90>
# <__main__.Node object at 0x000001D370F0CC30>
# <__main__.Node object at 0x000001D370F0CE10>
# <__main__.Node object at 0x000001D370F0CEB0>
# <__main__.Node object at 0x000001D370F0D090>
# <__main__.Node object at 0x000001D370F0D130>
# <__main__.Node object at 0x000001D370F0D310>
# <__main__.Node object at 0x000001D370F0D3B0>
# <__main__.Node object at 0x000001D370F0D590>
# <__main__.Node object at 0x000001D370F0D630>
# <__main__.Node object at 0x000001D370F0D810>
# <__main__.Node object at 0x000001D370F0D8B0>
# <__main__.Node object at 0x000001D370F0DA90>
# <__main__.Node object at 0x000001D370F0DB30>
# <__main__.Node object at 0x000001D370F0DD10>
# <__main__.Node object at 0x000001D370F0DDB0>
# <__main__.Node object at 0x000001D370F0DF90>
# <__main__.Node object at 0x000001D370F0E030>
# <__main__.Node object at 0x000001D370F0E210>
# <__main__.Node object at 0x000001D370F0E2B0>
# <__main__.Node object at 0x000001D370F0E490>
# <__main__.Node object at 0x000001D370F0E530>
# <__main__.Node object at 0x000001D370F0E710>
# <__main__.Node object at 0x000001D370F0E7B0>
# <__main__.Node object at 0x000001D370F0E990>
# <__main__.Node object at 0x000001D370F0EA30>
# <__main__.Node object at 0x000001D370F0EC10>
# <__main__.Node object at 0x000001D370F0ECB0>
# <__main__.Node object at 0x000001D370F0EE90>
# <__main__.Node object at 0x000001D370F0EF30>
# <__main__.Node object at 0x000001D370F0F110>
# <__main__.Node object at 0x000001D370F0F1B0>
# <__main__.Node object at 0x000001D370F0F390>
# <__main__.Node object at 0x000001D370F0F430>
# <__main__.Node object at 0x000001D370F0F610>
# <__main__.Node object at 0x000001D370F0F6B0>
# <__main__.Node object at 0x000001D370F0F890>
# <__main__.Node object at 0x000001D370F0F930>
# <__main__.Node object at 0x000001D370F0FB10>
# <__main__.Node object at 0x000001D370F0FBB0>
# <__main__.Node object at 0x000001D370F0FD90>
# <__main__.Node object at 0x000001D370F0FE30>
# <__main__.Node object at 0x000001D370F0C190>
# <__main__.Node object at 0x000001D370F0C230>
# <__main__.Node object at 0x000001D370E942D0>
# <__main__.Node object at 0x000001D370E94410>
# <__main__.Node object at 0x000001D370E944B0>
# <__main__.Node object at 0x000001D370E94690>
# <__main__.Node object at 0x000001D370E94730>
# <__main__.Node object at 0x000001D370E94910>
# <__main__.Node object at 0x000001D370E949B0>
# <__main__.Node object at 0x000001D370E94B90>
# <__main__.Node object at 0x000001D370E94C30>
# <__main__.Node object at 0x000001D370E94E10>
# <__main__.Node object at 0x000001D370E94EB0>
# <__main__.Node object at 0x000001D370E95090>
# <__main__.Node object at 0x000001D370E95130>
# <__main__.Node object at 0x000001D370E95310>
# <__main__.Node object at 0x000001D370E953B0>
# <__main__.Node object at 0x000001D370E95590>
# <__main__.Node object at 0x000001D370E95630>
# <__main__.Node object at 0x000001D370E95810>
# <__main__.Node object at 0x000001D370E958B0>
# <__main__.Node object at 0x000001D370E95A90>
# <__main__.Node object at 0x000001D370E95B30>
# <__main__.Node object at 0x000001D370E95D10>
# <__main__.Node object at 0x000001D370E95DB0>
# <__main__.Node object at 0x000001D370E95F90>
# <__main__.Node object at 0x000001D370E96030>
# <__main__.Node object at 0x000001D370E96210>
# <__main__.Node object at 0x000001D370E962B0>
# <__main__.Node object at 0x000001D370E96490>
# <__main__.Node object at 0x000001D370E96530>
# <__main__.Node object at 0x000001D370E96710>
# <__main__.Node object at 0x000001D370E967B0>
# <__main__.Node object at 0x000001D370E96990>
# <__main__.Node object at 0x000001D370E96A30>
# <__main__.Node object at 0x000001D370E96C10>
# <__main__.Node object at 0x000001D370E96CB0>
# <__main__.Node object at 0x000001D370E96E90>
# <__main__.Node object at 0x000001D370E96F30>
# <__main__.Node object at 0x000001D370E97110>
# <__main__.Node object at 0x000001D370E971B0>
# <__main__.Node object at 0x000001D370E97390>
# <__main__.Node object at 0x000001D370E97430>
# <__main__.Node object at 0x000001D370E97610>
# <__main__.Node object at 0x000001D370E976B0>
# <__main__.Node object at 0x000001D370E97890>
# <__main__.Node object at 0x000001D370E97930>
# <__main__.Node object at 0x000001D370E97B10>
# <__main__.Node object at 0x000001D370E97BB0>
# <__main__.Node object at 0x000001D370E97D90>
# <__main__.Node object at 0x000001D370E97E30>
# <__main__.Node object at 0x000001D370E94190>
# <__main__.Node object at 0x000001D370E94230>
# <__main__.Node object at 0x000001D3689202D0>
# <__main__.Node object at 0x000001D368920410>
# <__main__.Node object at 0x000001D3689204B0>
# <__main__.Node object at 0x000001D368920690>
# <__main__.Node object at 0x000001D368920730>
# <__main__.Node object at 0x000001D368920910>
# <__main__.Node object at 0x000001D3689209B0>
# <__main__.Node object at 0x000001D368920B90>
# <__main__.Node object at 0x000001D368920C30>
# <__main__.Node object at 0x000001D368920E10>
# <__main__.Node object at 0x000001D368920EB0>
# <__main__.Node object at 0x000001D368921090>
# <__main__.Node object at 0x000001D368921130>
# <__main__.Node object at 0x000001D368921310>
# <__main__.Node object at 0x000001D3689213B0>
# <__main__.Node object at 0x000001D368921590>
# <__main__.Node object at 0x000001D368921630>
# <__main__.Node object at 0x000001D368921810>
# <__main__.Node object at 0x000001D3689218B0>
# <__main__.Node object at 0x000001D368921A90>
# <__main__.Node object at 0x000001D368921B30>
# <__main__.Node object at 0x000001D368921D10>
# <__main__.Node object at 0x000001D368921DB0>
# <__main__.Node object at 0x000001D368921F90>
# <__main__.Node object at 0x000001D368922030>
# <__main__.Node object at 0x000001D368922210>
# <__main__.Node object at 0x000001D3689222B0>
# <__main__.Node object at 0x000001D368922490>
# <__main__.Node object at 0x000001D368922530>
# <__main__.Node object at 0x000001D368922710>
# <__main__.Node object at 0x000001D3689227B0>
# <__main__.Node object at 0x000001D368922990>
# <__main__.Node object at 0x000001D368922A30>
# <__main__.Node object at 0x000001D368922C10>
# <__main__.Node object at 0x000001D368922CB0>
# <__main__.Node object at 0x000001D368922E90>
# <__main__.Node object at 0x000001D368922F30>
# <__main__.Node object at 0x000001D368923110>
# <__main__.Node object at 0x000001D3689231B0>
# <__main__.Node object at 0x000001D368923390>
# <__main__.Node object at 0x000001D368923430>
# <__main__.Node object at 0x000001D368923610>
# <__main__.Node object at 0x000001D3689236B0>
# <__main__.Node object at 0x000001D368923890>
# <__main__.Node object at 0x000001D368923930>
# <__main__.Node object at 0x000001D368923B10>
# <__main__.Node object at 0x000001D368923BB0>
# <__main__.Node object at 0x000001D368923D90>
# <__main__.Node object at 0x000001D368923E30>
# <__main__.Node object at 0x000001D368920190>
# <__main__.Node object at 0x000001D368920230>
# <__main__.Node object at 0x000001D3689742D0>
# <__main__.Node object at 0x000001D368974410>
# <__main__.Node object at 0x000001D3689744B0>
# <__main__.Node object at 0x000001D368974690>
# <__main__.Node object at 0x000001D368974730>
# <__main__.Node object at 0x000001D368974910>
# <__main__.Node object at 0x000001D3689749B0>
# <__main__.Node object at 0x000001D368974B90>
# <__main__.Node object at 0x000001D368974C30>
# <__main__.Node object at 0x000001D368974E10>
# <__main__.Node object at 0x000001D368974EB0>
# <__main__.Node object at 0x000001D368975090>
# <__main__.Node object at 0x000001D368975130>
# <__main__.Node object at 0x000001D368975310>
# <__main__.Node object at 0x000001D3689753B0>
# <__main__.Node object at 0x000001D368975590>
# <__main__.Node object at 0x000001D368975630>
# <__main__.Node object at 0x000001D368975810>
# <__main__.Node object at 0x000001D3689758B0>
# <__main__.Node object at 0x000001D368975A90>
# <__main__.Node object at 0x000001D368975B30>
# <__main__.Node object at 0x000001D368975D10>
# <__main__.Node object at 0x000001D368975DB0>
# <__main__.Node object at 0x000001D368975F90>
# <__main__.Node object at 0x000001D368976030>
# <__main__.Node object at 0x000001D368976210>
# <__main__.Node object at 0x000001D3689762B0>
# <__main__.Node object at 0x000001D368976490>
# <__main__.Node object at 0x000001D368976530>
# <__main__.Node object at 0x000001D368976710>
# <__main__.Node object at 0x000001D3689767B0>
# <__main__.Node object at 0x000001D368976990>
# <__main__.Node object at 0x000001D368976A30>
# <__main__.Node object at 0x000001D368976C10>
# <__main__.Node object at 0x000001D368976CB0>
# <__main__.Node object at 0x000001D368976E90>
# <__main__.Node object at 0x000001D368976F30>
# <__main__.Node object at 0x000001D368977110>
# <__main__.Node object at 0x000001D3689771B0>
# <__main__.Node object at 0x000001D368977390>
# <__main__.Node object at 0x000001D368977430>
# <__main__.Node object at 0x000001D368977610>
# <__main__.Node object at 0x000001D3689776B0>
# <__main__.Node object at 0x000001D368977890>
# <__main__.Node object at 0x000001D368977930>
# <__main__.Node object at 0x000001D368977B10>
# <__main__.Node object at 0x000001D368977BB0>
# <__main__.Node object at 0x000001D368977D90>
# <__main__.Node object at 0x000001D368977E30>
# <__main__.Node object at 0x000001D368974190>
# <__main__.Node object at 0x000001D368974230>
# <__main__.Node object at 0x000001D3689C02D0>
# <__main__.Node object at 0x000001D3689C0410>
# <__main__.Node object at 0x000001D3689C04B0>
# <__main__.Node object at 0x000001D3689C0690>
# <__main__.Node object at 0x000001D3689C0730>
# <__main__.Node object at 0x000001D3689C0910>
# <__main__.Node object at 0x000001D3689C09B0>
# <__main__.Node object at 0x000001D3689C0B90>
# <__main__.Node object at 0x000001D3689C0C30>
# <__main__.Node object at 0x000001D3689C0E10>
# <__main__.Node object at 0x000001D3689C0EB0>
# <__main__.Node object at 0x000001D3689C1090>
# <__main__.Node object at 0x000001D3689C1130>
# <__main__.Node object at 0x000001D3689C1310>
# <__main__.Node object at 0x000001D3689C13B0>
# <__main__.Node object at 0x000001D3689C1590>
# <__main__.Node object at 0x000001D3689C1630>
# <__main__.Node object at 0x000001D3689C1810>
# <__main__.Node object at 0x000001D3689C18B0>
# <__main__.Node object at 0x000001D3689C1A90>
# <__main__.Node object at 0x000001D3689C1B30>
# <__main__.Node object at 0x000001D3689C1D10>
# <__main__.Node object at 0x000001D3689C1DB0>
# <__main__.Node object at 0x000001D3689C1F90>
# <__main__.Node object at 0x000001D3689C2030>
# <__main__.Node object at 0x000001D3689C2210>
# <__main__.Node object at 0x000001D3689C22B0>
# <__main__.Node object at 0x000001D3689C2490>
# <__main__.Node object at 0x000001D3689C2530>
# <__main__.Node object at 0x000001D3689C2710>
# <__main__.Node object at 0x000001D3689C27B0>
# <__main__.Node object at 0x000001D3689C2990>
# <__main__.Node object at 0x000001D3689C2A30>
# <__main__.Node object at 0x000001D3689C2C10>
# <__main__.Node object at 0x000001D3689C2CB0>
# <__main__.Node object at 0x000001D3689C2E90>
# <__main__.Node object at 0x000001D3689C2F30>
# <__main__.Node object at 0x000001D3689C3110>
# <__main__.Node object at 0x000001D3689C31B0>
# <__main__.Node object at 0x000001D3689C3390>
# <__main__.Node object at 0x000001D3689C3430>
# <__main__.Node object at 0x000001D3689C3610>
# <__main__.Node object at 0x000001D3689C36B0>
# <__main__.Node object at 0x000001D3689C3890>
# <__main__.Node object at 0x000001D3689C3930>
# <__main__.Node object at 0x000001D3689C3B10>
# <__main__.Node object at 0x000001D3689C3BB0>
# <__main__.Node object at 0x000001D3689C3D90>
# <__main__.Node object at 0x000001D3689C3E30>
# <__main__.Node object at 0x000001D3689C0190>
# <__main__.Node object at 0x000001D3685C1810>
# <__main__.Node object at 0x000001D3685C2CB0>
# <__main__.Node object at 0x000001D3685C2490>
# <__main__.Node object at 0x000001D3685C3250>
# <__main__.Node object at 0x000001D3685C3110>
# <__main__.Node object at 0x000001D3685C1090>
# <__main__.Node object at 0x000001D3685C3B10>
# <__main__.Node object at 0x000001D3685C1BD0>
# <__main__.Node object at 0x000001D3685C18B0>
# <__main__.Node object at 0x000001D3685C2030>
# <__main__.Node object at 0x000001D3685C2C10>
# <__main__.Node object at 0x000001D3685C1770>
# <__main__.Node object at 0x000001D3685C0730>
# <__main__.Node object at 0x000001D3685C1F90>
# <__main__.Node object at 0x000001D3685C2710>
# <__main__.Node object at 0x000001D3685C1590>
# <__main__.Node object at 0x000001D3685C09B0>
# <__main__.Node object at 0x000001D3685C2A30>
# <__main__.Node object at 0x000001D3685C1A90>
# <__main__.Node object at 0x000001D3685C0F50>
# <__main__.Node object at 0x000001D3685C3610>
# <__main__.Node object at 0x000001D3685C3ED0>
# <__main__.Node object at 0x000001D3685C0E10>
# <__main__.Node object at 0x000001D3685C0CD0>
# <__main__.Node object at 0x000001D3685C3890>
# <__main__.Node object at 0x000001D3685C1630>
# <__main__.Node object at 0x000001D3685C1DB0>
# <__main__.Node object at 0x000001D3685C27B0>
# <__main__.Node object at 0x000001D3685C0190>
# <__main__.Node object at 0x000001D3685C1D10>
# <__main__.Node object at 0x000001D3685C0EB0>
# <__main__.Node object at 0x000001D3685C2990>
# <__main__.Node object at 0x000001D3685C3BB0>
# <__main__.Node object at 0x000001D3685C1310>
# <__main__.Node object at 0x000001D3685C0050>
# <__main__.Node object at 0x000001D3685C05F0>
# <__main__.Node object at 0x000001D3685C0690>
# <__main__.Node object at 0x000001D3685C13B0>
# <__main__.Node object at 0x000001D3685C0550>
# <__main__.Node object at 0x000001D3685C3070>
# <__main__.Node object at 0x000001D3685C2D50>
# <__main__.Node object at 0x000001D3685C1E50>
# <__main__.Node object at 0x000001D3685C0910>
# <__main__.Node object at 0x000001D3685C3D90>
# <__main__.Node object at 0x000001D3685C3430>
# <__main__.Node object at 0x000001D3685C16D0>
# <__main__.Node object at 0x000001D3685C31B0>
# <__main__.Node object at 0x000001D3685C0410>
# <__main__.Node object at 0x000001D3685C1130>
# <__main__.Node object at 0x000001D3685C0B90>
# <__main__.Node object at 0x000001D3685C0230>
# <__main__.Node object at 0x000001D368671D10>
# <__main__.Node object at 0x000001D368672030>
# <__main__.Node object at 0x000001D368671F90>
# <__main__.Node object at 0x000001D368671E50>
# <__main__.Node object at 0x000001D368670EB0>
# <__main__.Node object at 0x000001D368670E10>
# <__main__.Node object at 0x000001D368671590>
# <__main__.Node object at 0x000001D368671130>
# <__main__.Node object at 0x000001D368671090>
# <__main__.Node object at 0x000001D3686731B0>
# <__main__.Node object at 0x000001D368673110>
# <__main__.Node object at 0x000001D368670410>
# <__main__.Node object at 0x000001D368670190>
# <__main__.Node object at 0x000001D368672490>
# <__main__.Node object at 0x000001D368672350>
# <__main__.Node object at 0x000001D368671810>
# <__main__.Node object at 0x000001D3686716D0>
# <__main__.Node object at 0x000001D368671630>
# <__main__.Node object at 0x000001D368671310>
# <__main__.Node object at 0x000001D3686707D0>
# <__main__.Node object at 0x000001D368670690>
# <__main__.Node object at 0x000001D368673B10>
# <__main__.Node object at 0x000001D3686732F0>
# <__main__.Node object at 0x000001D368673250>
# <__main__.Node object at 0x000001D368670910>
# <__main__.Node object at 0x000001D368673D90>
# <__main__.Node object at 0x000001D368673C50>
# <__main__.Node object at 0x000001D368673BB0>
# <__main__.Node object at 0x000001D368673430>
# <__main__.Node object at 0x000001D368673390>
# <__main__.Node object at 0x000001D368672530>
# <__main__.Node object at 0x000001D368671B30>
# <__main__.Node object at 0x000001D368671A90>
# <__main__.Node object at 0x000001D368670B90>
# <__main__.Node object at 0x000001D368673ED0>
# <__main__.Node object at 0x000001D368673E30>
# <__main__.Node object at 0x000001D368673610>
# <__main__.Node object at 0x000001D368672710>
# <__main__.Node object at 0x000001D3686739D0>
# <__main__.Node object at 0x000001D368673890>
# <__main__.Node object at 0x000001D368672990>
# <__main__.Node object at 0x000001D368672CB0>
# <__main__.Node object at 0x000001D368672C10>
# <__main__.Node object at 0x000001D368672AD0>
# <__main__.Node object at 0x000001D3686702D0>
# <__main__.Node object at 0x000001D368670050>
# <__main__.Node object at 0x000001D368672A30>
# <__main__.Node object at 0x000001D368672210>
# <__main__.Node object at 0x000001D3686709B0>
# <__main__.Node object at 0x000001D368672D50>
# <__main__.Node object at 0x000001D368670230>
# <__main__.Node object at 0x000001D368670CD0>
# <__main__.Node object at 0x000001D3685902D0>
# <__main__.Node object at 0x000001D368590410>
# <__main__.Node object at 0x000001D3685904B0>
# <__main__.Node object at 0x000001D368590690>
# <__main__.Node object at 0x000001D368590730>
# <__main__.Node object at 0x000001D368590910>
# <__main__.Node object at 0x000001D3685909B0>
# <__main__.Node object at 0x000001D368590B90>
# <__main__.Node object at 0x000001D368590C30>
# <__main__.Node object at 0x000001D368590E10>
# <__main__.Node object at 0x000001D368590EB0>
# <__main__.Node object at 0x000001D368591090>
# <__main__.Node object at 0x000001D368591130>
# <__main__.Node object at 0x000001D368591310>
# <__main__.Node object at 0x000001D3685913B0>
# <__main__.Node object at 0x000001D368591590>
# <__main__.Node object at 0x000001D368591630>
# <__main__.Node object at 0x000001D368591810>
# <__main__.Node object at 0x000001D3685918B0>
# <__main__.Node object at 0x000001D368591A90>
# <__main__.Node object at 0x000001D368591B30>
# <__main__.Node object at 0x000001D368591D10>
# <__main__.Node object at 0x000001D368591DB0>
# <__main__.Node object at 0x000001D368591F90>
# <__main__.Node object at 0x000001D368592030>
# <__main__.Node object at 0x000001D368592210>
# <__main__.Node object at 0x000001D3685922B0>
# <__main__.Node object at 0x000001D368592490>
# <__main__.Node object at 0x000001D368592530>
# <__main__.Node object at 0x000001D368592710>
# <__main__.Node object at 0x000001D3685927B0>
# <__main__.Node object at 0x000001D368592990>
# <__main__.Node object at 0x000001D368592A30>
# <__main__.Node object at 0x000001D368592C10>
# <__main__.Node object at 0x000001D368592CB0>
# <__main__.Node object at 0x000001D368592E90>
# <__main__.Node object at 0x000001D368592F30>
# <__main__.Node object at 0x000001D368593110>
# <__main__.Node object at 0x000001D3685931B0>
# <__main__.Node object at 0x000001D368593390>
# <__main__.Node object at 0x000001D368593430>
# <__main__.Node object at 0x000001D368593610>
# <__main__.Node object at 0x000001D368590190>
# <__main__.Node object at 0x000001D3685939D0>
# <__main__.Node object at 0x000001D368593B10>
# <__main__.Node object at 0x000001D368593BB0>
# <__main__.Node object at 0x000001D368593D90>
# <__main__.Node object at 0x000001D368593E30>
# <__main__.Node object at 0x000001D368593A70>
# <__main__.Node object at 0x000001D3684F2990>
# <__main__.Node object at 0x000001D3684F0410>
# <__main__.Node object at 0x000001D3684F0690>
# <__main__.Node object at 0x000001D3684F3D90>
# <__main__.Node object at 0x000001D3684F09B0>
# <__main__.Node object at 0x000001D3684F36B0>
# <__main__.Node object at 0x000001D3684F2530>
# <__main__.Node object at 0x000001D3684F0190>
# <__main__.Node object at 0x000001D3684F3E30>
# <__main__.Node object at 0x000001D3684F2A30>
# <__main__.Node object at 0x000001D3684F3930>
# <__main__.Node object at 0x000001D3684F0050>
# <__main__.Node object at 0x000001D3684F0C30>
# <__main__.Node object at 0x000001D3684F1D10>
# <__main__.Node object at 0x000001D3684F1810>
# <__main__.Node object at 0x000001D3684F1630>
# <__main__.Node object at 0x000001D3684F0910>
# <__main__.Node object at 0x000001D3684F1F90>
# <__main__.Node object at 0x000001D3684F1B30>
# <__main__.Node object at 0x000001D3684F3570>
# <__main__.Node object at 0x000001D3684F2C10>
# <__main__.Node object at 0x000001D3684F1590>
# <__main__.Node object at 0x000001D3684F11D0>
# <__main__.Node object at 0x000001D3684F31B0>
# <__main__.Node object at 0x000001D3684F2490>
# <__main__.Node object at 0x000001D3684F1A90>
# <__main__.Node object at 0x000001D3684F3890>
# <__main__.Node object at 0x000001D3684F1310>
# <__main__.Node object at 0x000001D3684F2710>
# <__main__.Node object at 0x000001D3684F0230>
# <__main__.Node object at 0x000001D3684F3390>
# <__main__.Node object at 0x000001D3684F04B0>
# <__main__.Node object at 0x000001D3684F2CB0>
# <__main__.Node object at 0x000001D3684F34D0>
# <__main__.Node object at 0x000001D3684F2030>
# <__main__.Node object at 0x000001D3684F0EB0>
# <__main__.Node object at 0x000001D3684F20D0>
# <__main__.Node object at 0x000001D3684F1BD0>
# <__main__.Node object at 0x000001D3684F0B90>
# <__main__.Node object at 0x000001D3684F2850>
# <__main__.Node object at 0x000001D3684F22B0>
# <__main__.Node object at 0x000001D3684F1450>
# <__main__.Node object at 0x000001D3684F3750>
# <__main__.Node object at 0x000001D3684F0E10>
# <__main__.Node object at 0x000001D3684F3610>
# <__main__.Node object at 0x000001D3684F1090>
# <__main__.Node object at 0x000001D3684F2350>
# <__main__.Node object at 0x000001D3684F3B10>
# <__main__.Node object at 0x000001D3684F1DB0>
# <__main__.Node object at 0x000001D3684F1950>
# <__main__.Node object at 0x000001D3684F1EF0>
# <__main__.Node object at 0x000001D3684F0730>
# <__main__.Node object at 0x000001D36854C2D0>
# <__main__.Node object at 0x000001D36854C410>
# <__main__.Node object at 0x000001D36854C4B0>
# <__main__.Node object at 0x000001D36854C690>
# <__main__.Node object at 0x000001D36854C730>
# <__main__.Node object at 0x000001D36854C910>
# <__main__.Node object at 0x000001D36854C9B0>
# <__main__.Node object at 0x000001D36854CB90>
# <__main__.Node object at 0x000001D36854CC30>
# <__main__.Node object at 0x000001D36854CE10>
# <__main__.Node object at 0x000001D36854CEB0>
# <__main__.Node object at 0x000001D36854D090>
# <__main__.Node object at 0x000001D36854D130>
# <__main__.Node object at 0x000001D36854D310>
# <__main__.Node object at 0x000001D36854D3B0>
# <__main__.Node object at 0x000001D36854D590>
# <__main__.Node object at 0x000001D36854D630>
# <__main__.Node object at 0x000001D36854D810>
# <__main__.Node object at 0x000001D36854D8B0>
# <__main__.Node object at 0x000001D36854DA90>
# <__main__.Node object at 0x000001D36854DB30>
# <__main__.Node object at 0x000001D36854DD10>
# <__main__.Node object at 0x000001D36854DDB0>
# <__main__.Node object at 0x000001D36854DF90>
# <__main__.Node object at 0x000001D36854E030>
# <__main__.Node object at 0x000001D36854E210>
# <__main__.Node object at 0x000001D36854E2B0>
# <__main__.Node object at 0x000001D36854E490>
# <__main__.Node object at 0x000001D36854E530>
# <__main__.Node object at 0x000001D36854E710>
# <__main__.Node object at 0x000001D36854E7B0>
# <__main__.Node object at 0x000001D36854E990>
# <__main__.Node object at 0x000001D36854EA30>
# <__main__.Node object at 0x000001D36854EC10>
# <__main__.Node object at 0x000001D36854ECB0>
# <__main__.Node object at 0x000001D36854EE90>
# <__main__.Node object at 0x000001D36854EF30>
# <__main__.Node object at 0x000001D36854F110>
# <__main__.Node object at 0x000001D36854F1B0>
# <__main__.Node object at 0x000001D36854F390>
# <__main__.Node object at 0x000001D36854F430>
# <__main__.Node object at 0x000001D36854F610>
# <__main__.Node object at 0x000001D36854F6B0>
# <__main__.Node object at 0x000001D36854F890>
# <__main__.Node object at 0x000001D36854F930>
# <__main__.Node object at 0x000001D36854FB10>
# <__main__.Node object at 0x000001D36854FBB0>
# <__main__.Node object at 0x000001D36854FD90>
# <__main__.Node object at 0x000001D36854FE30>
# <__main__.Node object at 0x000001D36854C190>
# <__main__.Node object at 0x000001D36854C230>
# <__main__.Node object at 0x000001D3684542D0>
# <__main__.Node object at 0x000001D368454410>
# <__main__.Node object at 0x000001D3684544B0>
# <__main__.Node object at 0x000001D368454690>
# <__main__.Node object at 0x000001D368454730>
# <__main__.Node object at 0x000001D368454910>
# <__main__.Node object at 0x000001D3684549B0>
# <__main__.Node object at 0x000001D368454B90>
# <__main__.Node object at 0x000001D368454C30>
# <__main__.Node object at 0x000001D368454E10>
# <__main__.Node object at 0x000001D368454EB0>
# <__main__.Node object at 0x000001D368455090>
# <__main__.Node object at 0x000001D368455130>
# <__main__.Node object at 0x000001D368455310>
# <__main__.Node object at 0x000001D3684553B0>
# <__main__.Node object at 0x000001D368455590>
# <__main__.Node object at 0x000001D368455630>
# <__main__.Node object at 0x000001D368455810>
# <__main__.Node object at 0x000001D3684558B0>
# <__main__.Node object at 0x000001D368455A90>
# <__main__.Node object at 0x000001D368455B30>
# <__main__.Node object at 0x000001D368455D10>
# <__main__.Node object at 0x000001D368455DB0>
# <__main__.Node object at 0x000001D368455F90>
# <__main__.Node object at 0x000001D368456030>
# <__main__.Node object at 0x000001D368456210>
# <__main__.Node object at 0x000001D3684562B0>
# <__main__.Node object at 0x000001D368456490>
# <__main__.Node object at 0x000001D368456530>
# <__main__.Node object at 0x000001D368456710>
# <__main__.Node object at 0x000001D3684567B0>
# <__main__.Node object at 0x000001D368456990>
# <__main__.Node object at 0x000001D368456A30>
# <__main__.Node object at 0x000001D368456C10>
# <__main__.Node object at 0x000001D368456CB0>
# <__main__.Node object at 0x000001D368456E90>
# <__main__.Node object at 0x000001D368456F30>
# <__main__.Node object at 0x000001D368457110>
# <__main__.Node object at 0x000001D3684571B0>
# <__main__.Node object at 0x000001D368457390>
# <__main__.Node object at 0x000001D368457430>
# <__main__.Node object at 0x000001D368457610>
# <__main__.Node object at 0x000001D3684576B0>
# <__main__.Node object at 0x000001D368457890>
# <__main__.Node object at 0x000001D368457930>
# <__main__.Node object at 0x000001D368457B10>
# <__main__.Node object at 0x000001D368457BB0>
# <__main__.Node object at 0x000001D368457D90>
# <__main__.Node object at 0x000001D368457E30>
# <__main__.Node object at 0x000001D368454190>
# <__main__.Node object at 0x000001D368454230>
# <__main__.Node object at 0x000001D37135FC50>
# <__main__.Node object at 0x000001D37135F6B0>
# <__main__.Node object at 0x000001D37135F430>
# <__main__.Node object at 0x000001D37135D090>
# <__main__.Node object at 0x000001D37135EF30>
# <__main__.Node object at 0x000001D37135F930>
# <__main__.Node object at 0x000001D37135D590>
# <__main__.Node object at 0x000001D37135E990>
# <__main__.Node object at 0x000001D37135FB10>
# <__main__.Node object at 0x000001D37135F4D0>
# <__main__.Node object at 0x000001D37135F1B0>
# <__main__.Node object at 0x000001D37135C190>
# <__main__.Node object at 0x000001D37135CE10>
# <__main__.Node object at 0x000001D37135D6D0>
# <__main__.Node object at 0x000001D37135CB90>
# <__main__.Node object at 0x000001D37135DD10>
# <__main__.Node object at 0x000001D37135EE90>
# <__main__.Node object at 0x000001D37135D1D0>
# <__main__.Node object at 0x000001D37135C730>
# <__main__.Node object at 0x000001D37135D130>
# <__main__.Node object at 0x000001D37135DDB0>
# <__main__.Node object at 0x000001D37135C690>
# <__main__.Node object at 0x000001D37135E210>
# <__main__.Node object at 0x000001D37135DB30>
# <__main__.Node object at 0x000001D37135F250>
# <__main__.Node object at 0x000001D37135D4F0>
# <__main__.Node object at 0x000001D37135E710>
# <__main__.Node object at 0x000001D37135DBD0>
# <__main__.Node object at 0x000001D37135D810>
# <__main__.Node object at 0x000001D37135F610>
# <__main__.Node object at 0x000001D37135EC10>
# <__main__.Node object at 0x000001D37135D310>
# <__main__.Node object at 0x000001D37135ED50>
# <__main__.Node object at 0x000001D37135F390>
# <__main__.Node object at 0x000001D37135E7B0>
# <__main__.Node object at 0x000001D37135C230>
# <__main__.Node object at 0x000001D37135F890>
# <__main__.Node object at 0x000001D37135FD90>
# <__main__.Node object at 0x000001D37135EA30>
# <__main__.Node object at 0x000001D37135C4B0>
# <__main__.Node object at 0x000001D37135FBB0>
# <__main__.Node object at 0x000001D37135FE30>
# <__main__.Node object at 0x000001D37135E2B0>
# <__main__.Node object at 0x000001D37135CF50>
# <__main__.Node object at 0x000001D37135E490>
# <__main__.Node object at 0x000001D37135C9B0>
# <__main__.Node object at 0x000001D37135F110>
# <__main__.Node object at 0x000001D37135CD70>
# <__main__.Node object at 0x000001D37135E850>
# <__main__.Node object at 0x000001D37135DA90>
# <__main__.Node object at 0x000001D37135C410>
# <__main__.Node object at 0x000001D3713002D0>
# <__main__.Node object at 0x000001D371300410>
# <__main__.Node object at 0x000001D3713004B0>
# <__main__.Node object at 0x000001D371300690>
# <__main__.Node object at 0x000001D371300730>
# <__main__.Node object at 0x000001D371300910>
# <__main__.Node object at 0x000001D3713009B0>
# <__main__.Node object at 0x000001D371300B90>
# <__main__.Node object at 0x000001D371300C30>
# <__main__.Node object at 0x000001D371300E10>
# <__main__.Node object at 0x000001D371300EB0>
# <__main__.Node object at 0x000001D371301090>
# <__main__.Node object at 0x000001D371301130>
# <__main__.Node object at 0x000001D371301310>
# <__main__.Node object at 0x000001D3713013B0>

# %%
# import copy
# saved_root = copy.deepcopy(root)
# root = saved_root

# %%
from IPython.display import clear_output
from itertools import count

total_reward = 0  # sum of rewards
test_env = loads(root_snapshot)  # env used to show progress

for i in count():

    # get best child
    best_child = root.select_bestq_leaf()

    # take action
    s, r, terminated, truncated, _ = test_env.step(best_child.action)

    # show image
    clear_output(True)
    plt.title("step %i" % i)
    plt.imshow(test_env.render())
    plt.show()

    total_reward += r
    if terminated or truncated:
        print("Finished with reward = ", total_reward)
        break

    # discard unrealized part of the tree [because not every child matters :(]
    for child in root.children:
        if child != best_child:
            child.safe_delete()

    # declare best child a new root
    root = Root.from_node(best_child)
    
    # expand
    plan_mcts(root, n_iters=1000)
    
    assert not root.is_leaf(), \
        "We ran out of tree! Need more planning! Try growing the tree right inside the loop."
# Out:
# Finished with reward =  30.0

# %% [markdown]
# ## Bonus assignments (10+pts each)
#
# There's a few things you might want to try if you want to dig deeper:
#
# ### Node selection and expansion
#
# "Analyze this" assignment
#
# UCB-1 is a weak bound as it relies on a very general bounds (Hoeffding Inequality, to be exact).
# * Try playing with the exploration parameter $C_p$. The theoretically optimal $C_p$ you can get from a max reward of the environment (max reward for CartPole is 200).
# * Use using a different exploration strategy (bayesian UCB, for example)
# * Expand not all but several random actions per `expand` call. See __the notes below__ for details.
#
# The goal is to find out what gives the optimal performance for `CartPole-v0` for different time budgets (i.e. different n_iter in plan_mcts.)
#
# Evaluate your results on `Acrobot-v1` - do the results change and if so, how can you explain it?
#
#
# ### Atari-RAM
#
# "Build this" assignment
#
# Don't forget to run:
# ```
# pip install gymnasium[atari,accept-rom-license]
# ```
#
# Apply MCTS to play Atari games. In particular, let's start with ```gym.make("MsPacman-ramDeterministic-v0")```.
#
# This requires two things:
# * Slightly modify WithSnapshots wrapper to work with atari.
#
#  * Atari has a special interface for snapshots:
#    ```
#    snapshot = self.env.ale.cloneState()
#    ...
#    self.env.ale.restoreState(snapshot)
#    ```
#  * Try it on the env above to make sure it does what you told it to.
#
# * Run MCTS on the game above.
#  * Start with small tree size to speed-up computations
#  * You will probably want to rollout for 10-100 steps (t_max) for starters
#  * Consider using discounted rewards (see __notes at the end__)
#  * Try a better rollout policy
#
#
# ### Integrate learning into planning
#
# Planning on each iteration is a costly thing to do. You can speed things up drastically if you train a classifier to predict which action will turn out to be best according to MCTS.
#
# To do so, just record which action did the MCTS agent take on each step and fit something to [state, mcts_optimal_action]
# * You can also use optimal actions from discarded states to get more (dirty) samples. Just don't forget to fine-tune without them.
# * It's also worth a try to use P(best_action|state) from your model to select best nodes in addition to UCB
# * If your model is lightweight enough, try using it as a rollout policy.
#
# __(bonus points)__ While CartPole is glorious enough, try expanding this to ```gym.make("MsPacmanDeterministic-v0")```
# * See previous section on how to wrap atari (you'll get points for both if you run this on atari)
#
#
# ### Integrate planning into learning (project, a LOT of points)
#
# Incorporate planning into the agent architecture.
#
# The goal is to implement [Value Iteration Networks](https://arxiv.org/abs/1602.02867)
#
# You will need to implement a special layer that performs value iteration-like update to a recurrent memory. This can be implemented the same way you did in the POMDP assignment.

# %% [markdown]
# ## Notes
#
#
# #### Assumptions
#
# The full list of assumptions is:
#
# * __Finite number of actions__: we enumerate all actions in `expand`.
# * __Episodic (finite) MDP__: while technically it works for infinite MDPs, we perform a rollout for $10^4$ steps. If you are knowingly infinite, please adjust `t_max` to something more reasonable.
# * __Deterministic MDP__: `Node` represents the single outcome of taking `self.action` in `self.parent`, and does not support the situation where taking an action in a state may lead to different rewards and next states.
# * __No discounted rewards__: we assume $\gamma=1$. If that isn't the case, you only need to change two lines in `rollout()` and use `my_qvalue = self.immediate_reward + gamma * child_qvalue` for `propagate()`.
# * __pickleable env__: won't work if e.g. your env is connected to a web-browser surfing the internet. For custom envs, you may need to modify get_snapshot/load_snapshot from `WithSnapshots`.
#
# #### On `get_best_leaf` and `expand` functions
#
# This MCTS implementation only selects leaf nodes for expansion.
# This doesn't break things down because `expand` adds all possible actions. Hence, all non-leaf nodes are by design fully expanded and shouldn't be selected.
#
# If you want to only add a few random action on each expand, you will also have to modify `get_best_leaf` to consider returning non-leafs.
#
# #### Rollout policy
#
# We use a simple uniform policy for rollouts. This introduces a negative bias to good situations that can be messed up completely with random bad action. As a simple example, if you tend to rollout with uniform policy, you better don't use sharp knives and walk near cliffs.
#
# You can improve that by integrating a reinforcement _learning_ algorithm with a computationally light agent. You can even train this agent on optimal policy found by the tree search.
#
# #### Contributions
# * Reusing some code from 5vision [solution for deephack.RL](https://github.com/5vision/uct_atari), code by Mikhail Pavlov
# * Using some code from [this gist](https://gist.github.com/blole/dfebbec182e6b72ec16b66cc7e331110)
#
# #### References
# * <a id="1">[1]</a> _Coulom R. (2007) Efficient Selectivity and Backup Operators in Monte-Carlo Tree Search. In: van den Herik H.J., Ciancarini P., Donkers H.H.L.M.. (eds) Computers and Games. CG 2006. Lecture Notes in Computer Science, vol 4630. Springer, Berlin, Heidelberg_
#
# * <a id="2">[2]</a> _Kocsis L., Szepesvári C. (2006) Bandit Based Monte-Carlo Planning. In: Fürnkranz J., Scheffer T., Spiliopoulou M. (eds) Machine Learning: ECML 2006. ECML 2006. Lecture Notes in Computer Science, vol 4212. Springer, Berlin, Heidelberg_
#
# * <a id="3">[3]</a> _Kocsis, Levente, Csaba Szepesvári, and Jan Willemson. "Improved monte-carlo search." Univ. Tartu, Estonia, Tech. Rep 1 (2006)._
#
# * <a id="4">[4]</a> _C. B. Browne et al., "A Survey of Monte Carlo Tree Search Methods," in IEEE Transactions on Computational Intelligence and AI in Games, vol. 4, no. 1, pp. 1-43, March 2012, doi: 10.1109/TCIAIG.2012.2186810._
